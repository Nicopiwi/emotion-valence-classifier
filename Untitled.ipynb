# %%
# %matplotlib qt

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mne
from mne.io import read_raw_eeglab
from mne_bids import BIDSPath, read_raw_bids, print_dir_tree, make_report, write_raw_bids

# %%
#!pip install datalad
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 4.0 MB/s eta 0:00:000:00:010:00:01:01
# ...
#   Using cached keyring-23.13.1-py3-none-any.whl (37 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.8/316.8 kB 4.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.0/110.0 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 2.4 MB/s eta 0:00:000:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 5.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# !datalad install https://github.com/OpenNeuroDatasets/ds003004.git
# Out:
# Cloning:   0%|                             | 0.00/2.00 [00:00<?, ? candidates/s]
# Enumerating: 0.00 Objects [00:00, ? Objects/s]
#
# Counting:   0%|                              | 0.00/1.81k [00:00<?, ? Objects/s]
#
# Compressing:   0%|                           | 0.00/1.17k [00:00<?, ? Objects/s]
#
# Receiving:   0%|                             | 0.00/1.81k [00:00<?, ? Objects/s]
# Receiving:  24%|█████▎                | 436/1.81k [00:00<00:00, 4.36k Objects/s]
# Receiving:  48%|██████████▌           | 872/1.81k [00:00<00:00, 4.32k Objects/s]
# Receiving:  77%|███████████████▍    | 1.40k/1.81k [00:00<00:00, 4.71k Objects/s]
#
# Resolving:   0%|                                | 0.00/250 [00:00<?, ? Deltas/s]
# [INFO   ] Remote origin not usable by git-annex; setting annex-ignore
# [INFO   ] https://github.com/OpenNeuroDatasets/ds003004.git/config download failed: Not Found
# [INFO   ] access to 1 dataset sibling s3-PRIVATE not auto-enabled, enable with:
# ...

# %%
raw_root_path = "./data/sub-01/eeg/sub-01_task-ImaginedEmotion_eeg.set"

# %%
# We start standarizing the data

montage = mne.channels.make_standard_montage("biosemi256")
raw = read_raw_eeglab(raw_root_path, preload=True)
raw
#write_raw_bids(raw, bids_root, subject="01", session="01", task="01", montage=montage)
# Out:
# Reading /home/kovix/Documents/Brainhack/emotion-valence-classifier/data/sub-01/eeg/sub-01_task-ImaginedEmotion_eeg.fdt
# Reading 0 ... 1154303  =      0.000 ...  4508.996 secs...
# /tmp/ipykernel_77412/691789901.py:4: RuntimeWarning: Estimated head radius (0.0 cm) is below the 3rd percentile for infant head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = read_raw_eeglab(raw_root_path, preload=True)
# <RawEEGLAB | sub-01_task-ImaginedEmotion_eeg.fdt, 224 x 1154304 (4509.0 s), ~1.93 GB, data loaded>

# %%
raw.plot_psd()
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 8.000 (s)
# <MNELineFigure size 1000x350 with 2 Axes>
# Traceback (most recent call last):
#   File "/home/kovix/miniconda3/lib/python3.10/site-packages/matplotlib/cbook/__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "/home/kovix/miniconda3/lib/python3.10/site-packages/matplotlib/widgets.py", line 2351, in release
#     self._release(event)
#   File "/home/kovix/miniconda3/lib/python3.10/site-packages/matplotlib/widgets.py", line 2822, in _release
#     self.onselect(vmin, vmax)
#   File "/home/kovix/miniconda3/lib/python3.10/site-packages/mne/viz/evoked.py", line 203, in _line_plot_onselect
#     plot_topomap(
#   File "/home/kovix/miniconda3/lib/python3.10/site-packages/mne/viz/topomap.py", line 967, in plot_topomap
#     return _plot_topomap(
# ...

# %%
raw.ch_names
# Out:
# ['A1',
#  'A2',
#  'A3',
#  'A4',
#  'A5',
#  'A6',
#  'A7',
#  'A8',
#  'A10',
#  'A11',
#  'A12',
#  'A13',
#  'A14',
#  'A15',
#  'A16',
#  'A17',
#  'A18',
#  'A19',
#  'A20',
#  'A21',
#  'A22',
#  'A23',
#  'A25',
#  'A26',
#  'A27',
#  'A29',
#  'A31',
#  'A32',
#  'B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'B6',
#  'B7',
#  'B8',
#  'B9',
#  'B10',
#  'B11',
#  'B12',
#  'B13',
#  'B14',
#  'B16',
#  'B17',
#  'B18',
#  'B19',
#  'B20',
#  'B21',
#  'B22',
#  'B23',
#  'B24',
#  'B25',
#  'B26',
#  'B27',
#  'B28',
#  'B29',
#  'B30',
#  'B31',
#  'B32',
#  'C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'C6',
#  'C7',
#  'C8',
#  'C9',
#  'C10',
#  'C11',
#  'C12',
#  'C13',
#  'C14',
#  'C15',
#  'C16',
#  'C17',
#  'C18',
#  'C19',
#  'C20',
#  'C21',
#  'C22',
#  'C23',
#  'C24',
#  'C25',
#  'C26',
#  'C27',
#  'C28',
#  'C29',
#  'C30',
#  'C31',
#  'C32',
#  'D1',
#  'D2',
#  'D3',
#  'D4',
#  'D5',
#  'D6',
#  'D7',
#  'D8',
#  'D9',
#  'D10',
#  'D12',
#  'D14',
# ...

# %%
raw.plot_sensors(show_names=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 2
#       1 raw.plot_sensors(show_names=True)
# ----> 2 plt.show()
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:3620, in _Backend.show(cls, block)
#    3618     block = not ipython_pylab and not is_interactive()
#    3619 if block:
# -> 3620     cls.mainloop()
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/backends/backend_qt.py:604, in FigureManagerQT.start_main_loop(cls)
#     602 qapp = QtWidgets.QApplication.instance()
#     603 if qapp:
# ...

# %%
raw.time_as_index([1, 2, 3])
# Out:
# array([256, 512, 768])

# %%
raw.pick_types(meg=False, eeg=True, eog=False)
# Out:
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# <RawEEGLAB | sub-01_task-ImaginedEmotion_eeg.fdt, 224 x 1154304 (4509.0 s), ~1.93 GB, data loaded>

# %%
raw.info.keys()
# Out:
# dict_keys(['acq_pars', 'acq_stim', 'ctf_head_t', 'description', 'dev_ctf_t', 'dig', 'experimenter', 'utc_offset', 'device_info', 'file_id', 'highpass', 'hpi_subsystem', 'kit_system_id', 'helium_info', 'line_freq', 'lowpass', 'meas_date', 'meas_id', 'proj_id', 'proj_name', 'subject_info', 'xplotter_layout', 'gantry_angle', 'bads', 'chs', 'comps', 'events', 'hpi_meas', 'hpi_results', 'projs', 'proc_history', 'custom_ref_applied', 'sfreq', 'dev_head_t', 'ch_names', 'nchan'])

# %%
#Events
#https://mne.tools/stable/auto_tutorials/intro/20_events_from_raw.html#stim-channel-defined

events, event_id = mne.events_from_annotations(raw)
event_id

# %%
events

# %%
cropping = raw.copy().crop(tmin=256, tmax=512).load_data()

# %%
cropping.plot()
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Channels marked as bad:
# ['A8', 'A11']

# %%
# !datalad get /home/kovix/Documents/Brainhack/emotion-valence-classifier/ds003004/sub-17/eeg
# Out:
# Total:   0%|                                    | 0.00/960M [00:00<?, ? Bytes/s]
# Get sub-17/e .. tion_eeg.fdt:   0%|             | 0.00/955M [00:00<?, ? Bytes/s]
# Get sub-17/e .. tion_eeg.fdt:  39%|█▉   | 376M/955M [00:00<00:00, 2.34G Bytes/s]
# Get sub-17/e .. tion_eeg.fdt:  43%|██▏  | 409M/955M [00:18<00:00, 2.34G Bytes/s]
# Get sub-17/e .. tion_eeg.fdt:  43%|██▏  | 409M/955M [00:18<00:34, 15.8M Bytes/s]
# Get sub-17/e .. tion_eeg.fdt:  43%|██▏  | 409M/955M [00:18<00:34, 15.7M Bytes/s]
# Get sub-17/e .. tion_eeg.fdt:  53%|██▋  | 505M/955M [00:38<00:28, 15.7M Bytes/s]
# Get sub-17/e .. tion_eeg.fdt:  53%|██▋  | 506M/955M [00:38<00:54, 8.30M Bytes/s]
# Get sub-17/e .. tion_eeg.fdt:  53%|██▋  | 507M/955M [00:38<00:54, 8.30M Bytes/s]
# Get sub-17/e .. tion_eeg.fdt:  59%|██▉  | 560M/955M [00:46<00:49, 8.00M Bytes/s]
# Get sub-17/e .. tion_eeg.fdt:  62%|███  | 593M/955M [00:50<00:46, 7.84M Bytes/s]
# Get sub-17/e .. tion_eeg.fdt:  64%|███▏ | 614M/955M [00:53<00:43, 7.77M Bytes/s]
# ...

# %%
raw2 = read_raw_eeglab("/home/kovix/Documents/Brainhack/emotion-valence-classifier/ds003004/sub-17/eeg/sub-17_task-ImaginedEmotion_eeg.set")
# Out:
# Reading /home/kovix/Documents/Brainhack/emotion-valence-classifier/ds003004/sub-17/eeg/sub-17_task-ImaginedEmotion_eeg.fdt
# /tmp/ipykernel_16593/3085734961.py:1: RuntimeWarning: Estimated head radius (0.0 cm) is below the 3rd percentile for infant head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw2 = read_raw_eeglab("/home/kovix/Documents/Brainhack/emotion-valence-classifier/ds003004/sub-17/eeg/sub-17_task-ImaginedEmotion_eeg.set")

# %%
raw2.plot()
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Channels marked as bad:
# none
